# %% [markdown]
# ## Pandas - Importing data

# %%
## import the pandas library in this cell
import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems_2019_first_6_months.csv``` into a dataframe named ```ems_19_first_df```

# %%
## import data and store in dataframe
pd.read_csv("ems_2019_first_6_months.csv")
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             190010111  2019-01-01 00:24:51              SICK
# 1             190010112  2019-01-01 00:25:22              DRUG
# 2             190010113  2019-01-01 00:25:52              DRUG
# 3             190010114  2019-01-01 00:25:52             OBMAJ
# 4             190010115  2019-01-01 00:26:03               EDP
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 6            SICK
# 1                                 4            DRUG
# 2                                 4            DRUG
# 3                                 3           OBMAJ
# 4                                 7             EDP
# ...                             ...             ...
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               6    01/01/2019 12:25:28 AM
# 1                               4    01/01/2019 12:25:39 AM
# 2                               4    01/01/2019 12:25:57 AM
# 3                               3    01/01/2019 12:26:13 AM
# 4                               7    01/01/2019 12:26:12 AM
# ...                           ...                       ...
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            37
# 1                                   Y                            17
# 2                                   Y                             5
# 3                                   Y                            21
# 4                                   Y                             9
# ...                               ...                           ...
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         01/01/2019 12:25:56 AM  ...            9.0                 2.0
# 1         01/01/2019 12:26:03 AM  ...           23.0                 9.0
# 2         01/01/2019 12:26:11 AM  ...           63.0                45.0
# 3         01/01/2019 12:26:24 AM  ...          106.0                32.0
# 4         01/01/2019 12:26:29 AM  ...          101.0                31.0
# ...                          ...  ...            ...                 ...
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                   103.0                      1.0                  12.0
# 1                   111.0                      4.0                  13.0
# 2                   318.0                     22.0                   8.0
# 3                   410.0                     27.0                   8.0
# 4                   414.0                     27.0                   5.0
# ...                   ...                      ...                   ...
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 0                        N  chunk10.csv
# 1                        N  chunk10.csv
# 2                        N  chunk13.csv
# 3                        N  chunk14.csv
# 4                        N  chunk14.csv
# ...                    ...          ...
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [754656 rows x 32 columns]

# %%
## call the first 10 rows
ems_19_first_df = pd.read_csv("ems_2019_first_6_months.csv")
ems_19_first_df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
# 5        190073272  2019-01-07 17:49:43               EDP
# 6        190073416  2019-01-07 18:27:54               EDP
# 7        190081434  2019-01-08 10:28:31            UNKNOW
# 8        190081743  2019-01-08 11:43:35            UNKNOW
# 9        190081744  2019-01-08 11:43:48               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
# 5                            7             EDP                          7
# 6                            7             EDP                          7
# 7                            4          UNKNOW                          4
# 8                            4          UNKNOW                          4
# 9                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# 1    01/01/2019 12:25:39 AM                              Y
# 2    01/01/2019 12:25:57 AM                              Y
# 3    01/01/2019 12:26:13 AM                              Y
# 4    01/01/2019 12:26:12 AM                              Y
# 5    01/07/2019 05:49:50 PM                              Y
# 6    01/07/2019 06:28:33 PM                              Y
# 7    01/08/2019 10:29:19 AM                              Y
# 8    01/08/2019 11:43:47 AM                              Y
# 9    01/08/2019 11:43:59 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    01/01/2019 12:25:56 AM  ...            9.0
# 1                            17    01/01/2019 12:26:03 AM  ...           23.0
# 2                             5    01/01/2019 12:26:11 AM  ...           63.0
# 3                            21    01/01/2019 12:26:24 AM  ...          106.0
# 4                             9    01/01/2019 12:26:29 AM  ...          101.0
# 5                             7    01/07/2019 05:50:04 PM  ...           17.0
# 6                            39    01/07/2019 06:28:44 PM  ...            6.0
# 7                            48    01/08/2019 10:29:36 AM  ...            NaN
# 8                            12    01/08/2019 11:43:55 AM  ...            7.0
# 9                            11    01/08/2019 11:44:30 AM  ...           44.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 2.0              103.0                      1.0
# 1                 9.0              111.0                      4.0
# 2                45.0              318.0                     22.0
# 3                32.0              410.0                     27.0
# 4                31.0              414.0                     27.0
# 5                 5.0              106.0                      2.0
# 6                 3.0              102.0                      2.0
# 7                 NaN                NaN                      NaN
# 8                 1.0              103.0                      2.0
# 9                16.0              204.0                      9.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  12.0                N                       N
# 1                  13.0                N                       N
# 2                   8.0                N                       N
# 3                   8.0                N                       N
# 4                   5.0                N                       N
# 5                  12.0                N                       N
# 6                  10.0                N                       N
# 7                   NaN                N                       N
# 8                  12.0                N                       N
# 9                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N   chunk10.csv
# 1                 N                   N   chunk10.csv
# 2                 N                   N   chunk13.csv
# 3                 N                   N   chunk14.csv
# 4                 N                   N   chunk14.csv
# 5                 N                   N  chunk149.csv
# 6                 N                   N  chunk149.csv
# 7                 N                   N  chunk149.csv
# 8                 N                   N  chunk149.csv
# 9                 N                   N  chunk149.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
ems_19_first_df.tail(5)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR       source
# 754651                   N  chunk82.csv
# 754652                   N  chunk82.csv
# 754653                   N  chunk82.csv
# 754654                   N  chunk82.csv
# 754655                   N  chunk82.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
ems_19_first_df.sample(20)
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 614367        191524298  2019-06-01 21:03:05              DRUG
# 231151        190610122  2019-03-02 00:38:14            STATEP
# 321061        190830398  2019-03-24 02:18:27              DRUG
# 639838        191582996  2019-06-07 15:37:51               MVA
# 343031        190882155  2019-03-29 13:04:03            UNKNOW
# 282134        190733100  2019-03-14 16:53:44              CVAC
# 550916        191382071  2019-05-18 12:43:56              DRUG
# 111260        190310506  2019-01-31 04:53:47            CARDBR
# 428634        191084230  2019-04-18 22:27:47              SICK
# 448673        191134343  2019-04-23 22:47:45               EDP
# 690888        191701640  2019-06-19 11:31:11            STATEP
# 503861        191272091  2019-05-07 13:06:48              SICK
# 97564         190273026  2019-01-27 18:14:27            RESPIR
# 404984        191031291  2019-04-13 09:15:54            UNKNOW
# 348004        190892824  2019-03-30 16:36:17               EDP
# 438602        191111684  2019-04-21 11:30:41            STATEP
# 322019        190831437  2019-03-24 10:18:09              CARD
# 648416        191602535  2019-06-09 14:44:49            INJURY
# 739898        191810404  2019-06-30 01:50:14            UNKNOW
# 730999        191791020  2019-06-28 07:48:27            INJURY
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 614367                            4            DRUG
# 231151                            2          STATEP
# 321061                            4            DRUG
# 639838                            6          MVAINJ
# 343031                            4             EDP
# 282134                            2            CVAC
# 550916                            4            DRUG
# 111260                            2          CARDBR
# 428634                            6            SICK
# 448673                            7             EDP
# 690888                            2          STATEP
# 503861                            6            SICK
# 97564                             4          RESPIR
# 404984                            4          UNKNOW
# 348004                            7             EDP
# 438602                            2          STATEP
# 322019                            3            SICK
# 648416                            5          INJURY
# 739898                            4          UNKNOW
# 730999                            5          INJURY
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 614367                          4    06/01/2019 09:03:24 PM
# 231151                          2    03/02/2019 12:38:19 AM
# 321061                          4    03/24/2019 02:18:43 AM
# 639838                          4    06/07/2019 03:37:58 PM
# 343031                          7    03/29/2019 02:39:31 PM
# 282134                          2    03/14/2019 04:56:13 PM
# 550916                          4    05/18/2019 12:44:19 PM
# 111260                          2    01/31/2019 04:54:01 AM
# 428634                          6    04/18/2019 10:28:03 PM
# 448673                          7    04/23/2019 10:47:52 PM
# 690888                          2    06/19/2019 11:31:21 AM
# 503861                          6    05/07/2019 01:07:40 PM
# 97564                           4    01/27/2019 06:14:51 PM
# 404984                          4    04/13/2019 09:16:04 AM
# 348004                          7    03/30/2019 04:36:36 PM
# 438602                          2    04/21/2019 11:30:53 AM
# 322019                          6    03/24/2019 10:19:35 AM
# 648416                          5    06/09/2019 02:45:09 PM
# 739898                          4    06/30/2019 01:50:33 AM
# 730999                          5    06/28/2019 07:48:39 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 614367                              Y                            19
# 231151                              Y                             5
# 321061                              Y                            16
# 639838                              Y                             7
# 343031                              Y                          5728
# 282134                              Y                           149
# 550916                              Y                            23
# 111260                              Y                            14
# 428634                              Y                            16
# 448673                              Y                             7
# 690888                              Y                            10
# 503861                              Y                            52
# 97564                               Y                            24
# 404984                              Y                            10
# 348004                              Y                            19
# 438602                              Y                            12
# 322019                              Y                            86
# 648416                              Y                            20
# 739898                              Y                            19
# 730999                              Y                            12
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 614367    06/01/2019 09:03:35 PM  ...           14.0                 4.0
# 231151    03/02/2019 12:38:34 AM  ...           70.0                45.0
# 321061    03/24/2019 02:18:59 AM  ...          110.0                25.0
# 639838    06/07/2019 03:38:25 PM  ...          121.0                50.0
# 343031    03/29/2019 02:40:50 PM  ...           26.0                 7.0
# 282134    03/14/2019 04:56:27 PM  ...           46.0                14.0
# 550916    05/18/2019 12:44:38 PM  ...           45.0                13.0
# 111260    01/31/2019 04:54:54 AM  ...          123.0                51.0
# 428634    04/18/2019 10:28:18 PM  ...           32.0                 9.0
# 448673    04/23/2019 10:48:06 PM  ...          107.0                24.0
# 690888    06/19/2019 11:31:32 AM  ...           14.0                 3.0
# 503861    05/07/2019 01:07:48 PM  ...           23.0                 8.0
# 97564     01/27/2019 06:15:09 PM  ...          109.0                20.0
# 404984    04/13/2019 09:16:11 AM  ...            1.0                 1.0
# 348004    03/30/2019 04:36:55 PM  ...           60.0                47.0
# 438602    04/21/2019 11:31:04 AM  ...          114.0                26.0
# 322019    03/24/2019 10:20:04 AM  ...           42.0                16.0
# 648416    06/09/2019 02:45:22 PM  ...           26.0                 9.0
# 739898    06/30/2019 01:50:59 AM  ...           43.0                18.0
# 730999    06/28/2019 07:48:59 AM  ...           46.0                14.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 614367              105.0                      2.0                  12.0
# 231151              314.0                     22.0                   9.0
# 321061              404.0                     24.0                   6.0
# 639838              502.0                     31.0                  11.0
# 343031              109.0                      5.0                  13.0
# 282134              205.0                     10.0                  15.0
# 550916              210.0                      8.0                  14.0
# 111260              503.0                     31.0                  11.0
# 428634              110.0                      5.0                  13.0
# 448673              408.0                     28.0                   6.0
# 690888              104.0                      2.0                  10.0
# 503861              111.0                      4.0                  13.0
# 97564               407.0                     25.0                   6.0
# 404984              101.0                      2.0                  10.0
# 348004              313.0                     21.0                   8.0
# 438602              401.0                     30.0                  12.0
# 322019              203.0                     12.0                  15.0
# 648416              109.0                      5.0                  13.0
# 739898              209.0                      8.0                  15.0
# 730999              205.0                      9.0                  15.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 614367                N                       N                 N
# 231151                N                       N                 N
# 321061                N                       N                 N
# 639838                N                       N                 N
# 343031                N                       N                 N
# 282134                N                       N                 N
# 550916                N                       N                 N
# 111260                N                       N                 N
# 428634                N                       N                 N
# 448673                N                       N                 N
# 690888                N                       N                 N
# 503861                N                       N                 N
# 97564                 N                       N                 N
# 404984                N                       N                 N
# 348004                N                       N                 N
# 438602                N                       N                 N
# 322019                N                       N                 N
# 648416                N                       N                 N
# 739898                N                       N                 N
# 730999                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 614367                   N  chunk156.csv
# 231151                   N  chunk152.csv
# 321061                   N  chunk153.csv
# 639838                   N  chunk156.csv
# 343031                   N  chunk153.csv
# 282134                   N  chunk152.csv
# 550916                   N  chunk155.csv
# 111260                   N  chunk150.csv
# 428634                   N  chunk154.csv
# 448673                   N  chunk154.csv
# 690888                   N  chunk156.csv
# 503861                   N  chunk154.csv
# 97564                    N  chunk150.csv
# 404984                   N  chunk153.csv
# 348004                   N  chunk153.csv
# 438602                   N  chunk154.csv
# 322019                   N  chunk153.csv
# 648416                   N  chunk156.csv
# 739898                   N  chunk157.csv
# 730999                   N  chunk157.csv
#
# [20 rows x 32 columns]

# %%
## get basic overview of the data

## what datatypes do the different columns hold?
#Ansuer: int64, object, float64

## how many rows and columns are there?
##Answer: 32 Columns, 754656 rows



ems_19_first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754656 entries, 0 to 754655
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 754656 non-null  int64
#  1   INCIDENT_DATETIME               754656 non-null  object
#  2   INITIAL_CALL_TYPE               754656 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     754656 non-null  int64
#  4   FINAL_CALL_TYPE                 754656 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       754656 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       749544 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  754656 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    754656 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       748561 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         729221 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  754656 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    729068 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   729221 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          522462 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     518867 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         754540 non-null  object
#  17  HELD_INDICATOR                  754656 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       748265 non-null  float64
#  19  BOROUGH                         754656 non-null  object
#  20  INCIDENT_DISPATCH_AREA          754656 non-null  object
#  21  ZIPCODE                         745086 non-null  float64
#  22  POLICEPRECINCT                  745102 non-null  float64
#  23  CITYCOUNCILDISTRICT             745071 non-null  float64
#  24  COMMUNITYDISTRICT               745101 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         744542 non-null  float64
#  26  CONGRESSIONALDISTRICT           745071 non-null  float64
#  27  REOPEN_INDICATOR                754656 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         754656 non-null  object
#  29  STANDBY_INDICATOR               754656 non-null  object
#  30  TRANSFER_INDICATOR              754656 non-null  object
#  31  source                          754656 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 184.2+ MB

# %%
ems_19_first_df.shape
# Out:
# (754656, 32)

# %% [markdown]
# ### In three separate cells, ingest the 3 other related datasets into this notebook:
#
# - ```ems_2019_last_6_months.csv``` into a dataframe named ```ems_19_last_df```
# - ```ems_2020_first_6_months.csv``` into a dataframe named ```ems_20_first_df```
# - ```ems_2020_last_6_months.csv``` into a dataframe named ```ems_20_last_df```
#
# We want to combine all 4 dataframes so we can run an analysis on the combined dataframes

# %%
ems_19_last_df = pd.read_csv ("ems_2019_last_6_months.csv")

# %%
### For last 6 months of 2019
## call the dataframe to see what you have
ems_19_last_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781740 entries, 0 to 781739
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 781740 non-null  int64
#  1   INCIDENT_DATETIME               781740 non-null  object
#  2   INITIAL_CALL_TYPE               781740 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     781740 non-null  int64
#  4   FINAL_CALL_TYPE                 781740 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       781740 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       776500 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  781740 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    781740 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       775362 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         756189 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  781740 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    756044 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   756164 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          526152 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     522569 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         781380 non-null  object
#  17  HELD_INDICATOR                  781740 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       775120 non-null  float64
#  19  BOROUGH                         781740 non-null  object
#  20  INCIDENT_DISPATCH_AREA          781740 non-null  object
#  21  ZIPCODE                         771206 non-null  float64
#  22  POLICEPRECINCT                  771235 non-null  float64
#  23  CITYCOUNCILDISTRICT             771187 non-null  float64
#  24  COMMUNITYDISTRICT               771234 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         770645 non-null  float64
#  26  CONGRESSIONALDISTRICT           771187 non-null  float64
#  27  REOPEN_INDICATOR                781740 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         781740 non-null  object
#  29  STANDBY_INDICATOR               781740 non-null  object
#  30  TRANSFER_INDICATOR              781740 non-null  object
#  31  source                          781740 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 190.9+ MB

# %%
### For first 6 months of 2020
## call the dataframe to see what you have
ems_20_first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741807 entries, 0 to 741806
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 741807 non-null  int64
#  1   INCIDENT_DATETIME               741807 non-null  object
#  2   INITIAL_CALL_TYPE               741807 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     741807 non-null  int64
#  4   FINAL_CALL_TYPE                 741807 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       741807 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       735936 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  741807 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    741807 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       734580 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         710059 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  741807 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    710008 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   710059 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          442033 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     437674 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         741456 non-null  object
#  17  HELD_INDICATOR                  741807 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       734627 non-null  float64
#  19  BOROUGH                         741807 non-null  object
#  20  INCIDENT_DISPATCH_AREA          741807 non-null  object
#  21  ZIPCODE                         734365 non-null  float64
#  22  POLICEPRECINCT                  734386 non-null  float64
#  23  CITYCOUNCILDISTRICT             734386 non-null  float64
#  24  COMMUNITYDISTRICT               734386 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         733944 non-null  float64
#  26  CONGRESSIONALDISTRICT           734386 non-null  float64
#  27  REOPEN_INDICATOR                741807 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         741807 non-null  object
#  29  STANDBY_INDICATOR               741807 non-null  object
#  30  TRANSFER_INDICATOR              741807 non-null  object
#  31  source                          741807 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 181.1+ MB

# %%
### For last 6 months of 2020
## call the dataframe to see what you have

ems_20_last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670755 entries, 0 to 670754
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 670755 non-null  int64
#  1   INCIDENT_DATETIME               670755 non-null  object
#  2   INITIAL_CALL_TYPE               670755 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     670755 non-null  int64
#  4   FINAL_CALL_TYPE                 670755 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       670755 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       668991 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  670755 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    670755 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       668017 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         653427 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  670755 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    653375 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   653398 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          416375 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     413494 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         670662 non-null  object
#  17  HELD_INDICATOR                  670755 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       668514 non-null  float64
#  19  BOROUGH                         670755 non-null  object
#  20  INCIDENT_DISPATCH_AREA          670755 non-null  object
#  21  ZIPCODE                         661922 non-null  float64
#  22  POLICEPRECINCT                  661949 non-null  float64
#  23  CITYCOUNCILDISTRICT             661949 non-null  float64
#  24  COMMUNITYDISTRICT               661945 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         661365 non-null  float64
#  26  CONGRESSIONALDISTRICT           661949 non-null  float64
#  27  REOPEN_INDICATOR                670755 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         670755 non-null  object
#  29  STANDBY_INDICATOR               670755 non-null  object
#  30  TRANSFER_INDICATOR              670755 non-null  object
#  31  source                          670755 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 163.8+ MB

# %% [markdown]
# ### Check if all the column headers are identical (down to the same order)
# We need to confirm they are the same before we combine them

# %%
## headers for first 6 months of 2019
ems_19_first_df.head ()
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        190010111  2019-01-01 00:24:51              SICK
# 1        190010112  2019-01-01 00:25:22              DRUG
# 2        190010113  2019-01-01 00:25:52              DRUG
# 3        190010114  2019-01-01 00:25:52             OBMAJ
# 4        190010115  2019-01-01 00:26:03               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            6            SICK                          6
# 1                            4            DRUG                          4
# 2                            4            DRUG                          4
# 3                            3           OBMAJ                          3
# 4                            7             EDP                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    01/01/2019 12:25:28 AM                              Y
# 1    01/01/2019 12:25:39 AM                              Y
# 2    01/01/2019 12:25:57 AM                              Y
# 3    01/01/2019 12:26:13 AM                              Y
# 4    01/01/2019 12:26:12 AM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    01/01/2019 12:25:56 AM  ...            9.0
# 1                            17    01/01/2019 12:26:03 AM  ...           23.0
# 2                             5    01/01/2019 12:26:11 AM  ...           63.0
# 3                            21    01/01/2019 12:26:24 AM  ...          106.0
# 4                             9    01/01/2019 12:26:29 AM  ...          101.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 2.0              103.0                      1.0
# 1                 9.0              111.0                      4.0
# 2                45.0              318.0                     22.0
# 3                32.0              410.0                     27.0
# 4                31.0              414.0                     27.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  12.0                N                       N
# 1                  13.0                N                       N
# 2                   8.0                N                       N
# 3                   8.0                N                       N
# 4                   5.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR       source
# 0                 N                   N  chunk10.csv
# 1                 N                   N  chunk10.csv
# 2                 N                   N  chunk13.csv
# 3                 N                   N  chunk14.csv
# 4                 N                   N  chunk14.csv
#
# [5 rows x 32 columns]

# %%
## headers for first 6 months of 2020
ems_20_last_df.head()
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201853344  2020-07-03 19:51:35            MVAINJ
# 1        201861781  2020-07-04 13:38:45            INJURY
# 2        201862931  2020-07-04 19:06:08            INJURY
# 3        201870048  2020-07-05 00:09:31              SICK
# 4        201870159  2020-07-05 00:31:24              EDPC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            4          MVAINJ                          4
# 1                            5          INJURY                          5
# 2                            5          INJURY                          5
# 3                            6            SICK                          6
# 4                            7            SICK                          6
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    07/03/2020 07:52:54 PM                              Y
# 1    07/04/2020 01:38:55 PM                              Y
# 2    07/04/2020 07:06:34 PM                              Y
# 3                       NaN                              N
# 4                       NaN                              N
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            79    07/03/2020 07:53:13 PM  ...            NaN
# 1                            10    07/04/2020 01:39:01 PM  ...           20.0
# 2                            26    07/04/2020 07:06:53 PM  ...           60.0
# 3                             0                       NaN  ...           46.0
# 4                             0                       NaN  ...           43.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 NaN                NaN                      NaN
# 1                 3.0              107.0                      3.0
# 2                47.0              313.0                     21.0
# 3                14.0              205.0                     10.0
# 4                17.0              209.0                     12.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                   NaN                N                       N
# 1                  10.0                N                       N
# 2                   8.0                N                       N
# 3                  15.0                N                       N
# 4                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N  chunk172.csv
# 1                 N                   N  chunk172.csv
# 2                 N                   N  chunk172.csv
# 3                 N                   N  chunk172.csv
# 4                 N                   N  chunk172.csv
#
# [5 rows x 32 columns]

# %%
## check if they are the same
list (ems_19_first_df.columns)
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
list (ems_20_last_df.columns)
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
## creater headers list for last 6 months of 2019 and 2020
list (ems_20_last_df.columns) == list (ems_19_first_df.columns)
# Out:
# True

# %%
## check if one of the first is equal to one of the last
## I didn't understand this question

# %%
## now confirm that the two lasts are the same
##I didn't understand this question.

##I compared the four databases and they are the same

# %%
list (ems_19_last_df.columns)
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
list (ems_20_first_df.columns)
# Out:
# ['CAD_INCIDENT_ID',
#  'INCIDENT_DATETIME',
#  'INITIAL_CALL_TYPE',
#  'INITIAL_SEVERITY_LEVEL_CODE',
#  'FINAL_CALL_TYPE',
#  'FINAL_SEVERITY_LEVEL_CODE',
#  'FIRST_ASSIGNMENT_DATETIME',
#  'VALID_DISPATCH_RSPNS_TIME_INDC',
#  'DISPATCH_RESPONSE_SECONDS_QY',
#  'FIRST_ACTIVATION_DATETIME',
#  'FIRST_ON_SCENE_DATETIME',
#  'VALID_INCIDENT_RSPNS_TIME_INDC',
#  'INCIDENT_RESPONSE_SECONDS_QY',
#  'INCIDENT_TRAVEL_TM_SECONDS_QY',
#  'FIRST_TO_HOSP_DATETIME',
#  'FIRST_HOSP_ARRIVAL_DATETIME',
#  'INCIDENT_CLOSE_DATETIME',
#  'HELD_INDICATOR',
#  'INCIDENT_DISPOSITION_CODE',
#  'BOROUGH',
#  'INCIDENT_DISPATCH_AREA',
#  'ZIPCODE',
#  'POLICEPRECINCT',
#  'CITYCOUNCILDISTRICT',
#  'COMMUNITYDISTRICT',
#  'COMMUNITYSCHOOLDISTRICT',
#  'CONGRESSIONALDISTRICT',
#  'REOPEN_INDICATOR',
#  'SPECIAL_EVENT_INDICATOR',
#  'STANDBY_INDICATOR',
#  'TRANSFER_INDICATOR',
#  'source']

# %%
list (ems_19_first_df.columns) == list (ems_20_last_df.columns) == list (ems_19_last_df.columns) == list (ems_20_first_df.columns)
# Out:
# True

# %% [markdown]
# ## Combine the 4 dataframes

# %%
## create a list to combine all 
com_ems = pd.concat([ems_19_last_df, ems_20_first_df,ems_20_last_df, ems_19_first_df])

# %%
## combine the dfs
com_ems
# Out:
#         CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             191853909  2019-07-04 21:07:53              DRUG
# 1             191864927  2019-07-05 21:09:53            MVAINJ
# 2             191870823  2019-07-06 05:32:12            INJURY
# 3             191870824  2019-07-06 05:33:49               UNC
# 4             191870897  2019-07-06 06:20:26            INJURY
# ...                 ...                  ...               ...
# 754651        190010106  2019-01-01 00:24:12              DRUG
# 754652        190010107  2019-01-01 00:24:14               UNC
# 754653        190010108  2019-01-01 00:24:16            INJMAJ
# 754654        190010109  2019-01-01 00:24:23              CARD
# 754655        190010110  2019-01-01 00:24:35              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 4            DRUG
# 1                                 4          MVAINJ
# 2                                 5          INJURY
# 3                                 2             UNC
# 4                                 5          INJURY
# ...                             ...             ...
# 754651                            4            DRUG
# 754652                            2             UNC
# 754653                            3          INJMAJ
# 754654                            3            CARD
# 754655                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               4    07/04/2019 09:08:16 PM
# 1                               4    07/05/2019 09:10:10 PM
# 2                               5    07/06/2019 05:32:49 AM
# 3                               2    07/06/2019 05:33:57 AM
# 4                               5    07/06/2019 06:20:43 AM
# ...                           ...                       ...
# 754651                          4    01/01/2019 12:28:52 AM
# 754652                          2    01/01/2019 12:24:38 AM
# 754653                          3    01/01/2019 12:25:50 AM
# 754654                          3    01/01/2019 12:25:08 AM
# 754655                          4    01/01/2019 12:25:28 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            23
# 1                                   Y                            17
# 2                                   Y                            37
# 3                                   Y                             8
# 4                                   Y                            17
# ...                               ...                           ...
# 754651                              Y                           280
# 754652                              Y                            24
# 754653                              Y                            94
# 754654                              Y                            45
# 754655                              Y                            53
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0         07/04/2019 09:08:26 PM  ...            NaN                 NaN
# 1         07/05/2019 09:10:20 PM  ...            NaN                 NaN
# 2         07/06/2019 05:33:40 AM  ...           47.0                12.0
# 3         07/06/2019 05:34:25 AM  ...           32.0                 9.0
# 4         07/06/2019 06:20:53 AM  ...            NaN                 NaN
# ...                          ...  ...            ...                 ...
# 754651    01/01/2019 12:28:52 AM  ...           14.0                 3.0
# 754652    01/01/2019 12:24:57 AM  ...           14.0                 3.0
# 754653    01/01/2019 12:25:50 AM  ...           18.0                 4.0
# 754654    01/01/2019 12:25:27 AM  ...           50.0                14.0
# 754655    01/01/2019 12:25:40 AM  ...           62.0                47.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                     NaN                      NaN                   NaN
# 1                     NaN                      NaN                   NaN
# 2                   212.0                     11.0                  16.0
# 3                   110.0                      5.0                  13.0
# 4                     NaN                      NaN                   NaN
# ...                   ...                      ...                   ...
# 754651              105.0                      2.0                  12.0
# 754652              105.0                      2.0                  12.0
# 754653              105.0                      2.0                  12.0
# 754654              208.0                     10.0                  13.0
# 754655              311.0                     20.0                  10.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# ...                 ...                     ...               ...
# 754651                N                       N                 N
# 754652                N                       N                 N
# 754653                N                       N                 N
# 754654                N                       N                 N
# 754655                N                       N                 N
#
#         TRANSFER_INDICATOR        source
# 0                        N  chunk157.csv
# 1                        N  chunk157.csv
# 2                        N  chunk157.csv
# 3                        N  chunk157.csv
# 4                        N  chunk157.csv
# ...                    ...           ...
# 754651                   N   chunk82.csv
# 754652                   N   chunk82.csv
# 754653                   N   chunk82.csv
# 754654                   N   chunk82.csv
# 754655                   N   chunk82.csv
#
# [2948958 rows x 32 columns]

# %% [markdown]
# #### Confirm that their row totals add up to the correct number

# %%
## how many rows does the combined df have
com_ems.shape
# Out:
# (2948958, 32)

# %%
## get total rows when you add up all the individual dataframes

com_ems.shape [0] == ems_19_last_df.shape[0] + ems_19_first_df.shape[0] + ems_20_first_df.shape[0] + ems_20_last_df.shape[0]
# Out:
# True

# %% [markdown]
# ## Ingest Massive Dataset
#
# Step 1. Open this dataset in Excel first. What happened?
#
# Step 2. Open this data set in Pandas.

# %%
## import global_temps.csv into a df called temps_df

temps_df = pd.read_csv("global_temps.csv")

# %% [markdown]
# ## How many rows of data does this dataset have?

# %%
## 2_906_327

temps_df.shape
# Out:
# (2906327, 7)

# %% [markdown]
# ## Targeting an Excel sheet
#
# We need the Customs and Border Protection data in this ```multi-data.xlsx``` workbook.
#
# Note that this is an excerpt of the actual CBP data.

# %%
### import it here
multi = pd.read_excel("multi-data.xlsx", sheet_name="CBP")

# %%
multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95727 entries, 0 to 95726
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  95722 non-null  object
#  1   Unnamed: 1  95224 non-null  object
#  2   Unnamed: 2  95507 non-null  object
#  3   Unnamed: 3  95717 non-null  object
#  4   Unnamed: 4  95722 non-null  object
#  5   Unnamed: 5  95722 non-null  object
#  6   Unnamed: 6  95722 non-null  object
#  7   Unnamed: 7  95722 non-null  object
#  8   Unnamed: 8  1 non-null      object
# dtypes: object(9)
# memory usage: 6.6+ MB

# %%
multi.shape()
## Why did this mistake happen? Also, I'm trying to know the column names but there are some spaces in between
##How do I do that?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/51/zfcz7v952f74skxnnh3c0g8m0000gn/T/ipykernel_9715/3016141818.py in <module>
# ----> 1 multi.shape()
#
# TypeError: 'tuple' object is not callable

# %%
pd.read_excel("7-week-homework/multi-data.xlsx", sheet_name = "CBP")

## I'm leaving this mistake here as a personal note. I wonder why this happened when I wrote the same code
## in the cell above and it worked.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/51/zfcz7v952f74skxnnh3c0g8m0000gn/T/ipykernel_9715/1913579941.py in <module>
# ----> 1 pd.read_excel("7-week-homework/multi-data.xlsx", sheet_name = "CBP")
#       2
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '7-week-homework/multi-data.xlsx'
